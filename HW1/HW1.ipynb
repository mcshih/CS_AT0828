# %% [markdown]
# ## HW1: Linear Regression using Gradient Descent
# In hw1, you need to implement linear regression by using only numpy, then train your implemented model by the provided dataset and test the performance with testing data
#
# Please note that only **NUMPY** can be used to implement your model, you will get no points by simply calling sklearn.linear_model.LinearRegression

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data

# %%
train_df = pd.read_csv("train_data.csv")
x_train, y_train = train_df['x_train'], train_df['y_train']

# %%
plt.plot(x_train, y_train, '.')

# %% [markdown]
# ## Train your model
# ### Pseudo code:
# 1. Random initialize the weights, intercepts of the linear model
#
# **for i in range(iteration)**
#
#     2. Feed foward the training data into the model, get the output prediction
#     3. Calculating training loss by Mean Square Error of predcition and ground truth data
#     4. Calculating the gradients
#     5. Updating the weights and intercepts by the gradients * learning rate
#
# **End of training**

# %%
weight = np.random.randn()
intercept = np.random.randn()

lr = 1e-1  # The learning Rate
iteration = 100  # The number of iterations to perform gradient descent

n = float(len(x_train)) # Number of elements in X

error = []
# Performing Gradient Descent 
for i in range(iteration):
    y_pred = weight * x_train + intercept  # The current predicted value of Y
    loss = np.square(y_train-y_pred).mean()
    D_weight = -(2/n)*sum(x_train*(y_train-y_pred))
    D_intercept = -(2/n)*sum(y_train-y_pred)
    weight -= lr * D_weight  # Update m
    intercept -= lr * D_intercept  # Update c
    error.append(loss)
plt.plot(range(iteration), error, '.')

# %%
def model(X):
    y_pred = weight*X + intercept
    return y_pred
y_pred = model(x_train)
plt.plot(x_train, y_train, '.')
plt.plot([min(x_train), max(x_train)], [min(y_pred), max(y_pred)], color='red')  # regression line

# %% [markdown]
# ## Test the performance on the testing data
# Inference the test data (x_test) by your model and calculate the MSE of (y_test, y_pred)

# %%
test_data = pd.read_csv("test_data.csv")
x_test, y_test = test_data['x_test'], test_data['y_test']

# %%
y_pred = model(x_test)
print("MSE: {}".format(np.square(y_test-y_pred).mean()))
plt.plot(x_test, y_test, '.')
plt.plot([min(x_test), max(x_test)], [min(y_pred), max(y_pred)], color='red')  # regression line
# Out:
# MSE: 0.06870297325114488

# %%
print("weight: {}, intercept: {}.".format(weight, intercept))
# Out:
# weight: 0.8179703767061276, intercept: 0.7845650819526501.
